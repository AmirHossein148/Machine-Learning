# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('insurance.csv')

# %%
data.drop(['charges'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
data[['sex','smoker','region']] = encoder.fit_transform(data[['sex','smoker','region']])

# %%
data['smoker'].value_counts()
# Out:
# smoker
# 0.0    1064
# 1.0     274
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(data.drop(['region'],axis=1),data['region'],test_size=.2,random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C':[0.1,1,10], 'kernel':['rbf']}
grid = GridSearchCV(SVC(), param_grid, cv=5,scoring='f1',verbose=3)
grid.fit(X_train, y_train)

print("Best SVM params:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ...................C=0.1, kernel=rbf;, score=nan total time=   0.1s
# [CV 2/5] END ...................C=0.1, kernel=rbf;, score=nan total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import numpy as np

X = data.drop(['sex'],axis=1)
y = data['sex']

model = LogisticRegression()
scores = cross_val_score(model, X, y, cv=kf, scoring='f1')

print("f1 per fold:", scores)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.linear_model import LogisticRegression , LinearRegression
from sklearn.svm import SVC

model_log = LogisticRegression(class_weight='balanced')
model_log.fit(X_train_scaled,y_train)

model_svm = SVC(C=.1,kernel='rbf',class_weight='balanced')
model_svm.fit(X_train_scaled,y_train)
# Out:
# SVC(C=0.1, class_weight='balanced')

# %%
from sklearn.metrics import accuracy_score , f1_score

print(f1_score(y_val,model_log.predict(X_val_scaled),average='weighted'))
print(f1_score(model_svm.predict(X_val_scaled),y_val,average='weighted'))
# Out:
# 0.35027087960051767
# 0.34160884506275274

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
import numpy as np

model = LinearRegression()
scores = cross_val_score(model, X, y, cv=kf, scoring='r2')

print("R2 per fold:", scores)
# Out:
# R2 per fold: [0.78334631 0.74026709 0.79566892 0.63244564 0.75199803]

# %%
from sklearn.linear_model import LinearRegression

model_lin = LinearRegression()
model_lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
print(r2_score(y_val,model_lin.predict(X_val)))
# Out:
# 0.7833463107364539
